# %%
# %run crime_interacive_ipywidgets.py
# Out:
# ...
# Output()

# %%
df = crime_table.filtered_data[crime_table.filtered_data['year'] > 2010]
df
# Out:
#     index freq     unit country_name                     crime_info  year  \
# 3    3040    A  P_HTHAB      Albania  Acts against computer systems  2011
# 4    3814    A  P_HTHAB      Albania  Acts against computer systems  2012
# 5    4588    A  P_HTHAB      Albania  Acts against computer systems  2013
# 6    5362    A  P_HTHAB      Albania  Acts against computer systems  2014
# 7    6136    A  P_HTHAB      Albania  Acts against computer systems  2015
# 8    6910    A  P_HTHAB      Albania  Acts against computer systems  2016
# 9    7684    A  P_HTHAB      Albania  Acts against computer systems  2017
# 10   8458    A  P_HTHAB      Albania  Acts against computer systems  2018
# 11   9232    A  P_HTHAB      Albania  Acts against computer systems  2019
# 12  10006    A  P_HTHAB      Albania  Acts against computer systems  2020
# 13  10780    A  P_HTHAB      Albania  Acts against computer systems  2021
# 14  11554    A  P_HTHAB      Albania  Acts against computer systems  2022
#
# ...
